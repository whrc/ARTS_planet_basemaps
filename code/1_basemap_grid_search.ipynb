# %% [markdown]
# # Search Planet Basemap API
# This script searches the basemap API for basemap grids across the circumpolar region.

# %% [markdown]
# ## API and Package Set-Up

# %%
import os
import json
import requests
import urllib.request
import re
import numpy as np
import pandas as pd
import geopandas as gpd
import shapely as shp
from pprint import pprint

# %%
# Get Planet API Key
# %load_ext dotenv
# %dotenv

api_key = os.getenv('PL_BM_API_KEY')

# %% [markdown]
# ## Search for Basemap

# %%
year_of_interest = 2024

# %%
#setup Planet base URL
API_URL = "https://api.planet.com/basemaps/v1/mosaics"

#setup session
session = requests.Session()

#authenticate
session.auth = (api_key, "")

# %%
# make get request to access mosaic from basemaps API
res = session.get(API_URL)

#response status code - should be 200 if there were no errors
print(res.status_code)

#print metadata for mosaic
mosaic = res.json()
print(json.dumps(mosaic, indent=2))
# Out:
# 200
# {
#   "_links": {
#     "_next": "https://api.planet.com/basemaps/v1/mosaics?_page=2&_page_size=50&api_key=PLAK0a0262a75eb34455bb250697655805f5",
#     "_self": "https://api.planet.com/basemaps/v1/mosaics?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#   },
#   "mosaics": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/48fff803-4104-49bc-b913-7467b7a5ffb5?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/48fff803-4104-49bc-b913-7467b7a5ffb5/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_01_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -179,
#         -56,
#         180,
#         58
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2016-01-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 2048,
#         "resolution": 4.777314267823516
#       },
#       "id": "48fff803-4104-49bc-b913-7467b7a5ffb5",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene",
#         "REOrthoTile"
#       ],
#       "last_acquired": "2016-02-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2016_01_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/a97687cf-65db-4f34-ab2c-2ef7596a24ce?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/a97687cf-65db-4f34-ab2c-2ef7596a24ce/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_02_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -179,
#         -56,
#         180,
#         68
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2016-02-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 2048,
#         "resolution": 4.777314267823516
#       },
#       "id": "a97687cf-65db-4f34-ab2c-2ef7596a24ce",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene",
#         "REOrthoTile"
#       ],
#       "last_acquired": "2016-03-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2016_02_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/cfd6a60f-ec1e-491d-a885-e06d43990bd5?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/cfd6a60f-ec1e-491d-a885-e06d43990bd5/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_03_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -180,
#         -55,
#         180,
#         76
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2016-03-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 2048,
#         "resolution": 4.777314267823516
#       },
#       "id": "cfd6a60f-ec1e-491d-a885-e06d43990bd5",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene",
#         "REOrthoTile"
#       ],
#       "last_acquired": "2016-04-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2016_03_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/e6eaab79-7209-46cd-b187-1046e302e8bb?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/e6eaab79-7209-46cd-b187-1046e302e8bb/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_04_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -180,
#         -53,
#         180,
#         65
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2016-04-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 2048,
#         "resolution": 4.777314267823516
#       },
#       "id": "e6eaab79-7209-46cd-b187-1046e302e8bb",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene",
#         "REOrthoTile"
#       ],
#       "last_acquired": "2016-05-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2016_04_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/ab910c9a-242f-47e2-8c3c-debbe256a724?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/ab910c9a-242f-47e2-8c3c-debbe256a724/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_05_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -180,
#         -55,
#         180,
#         70
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2016-05-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 2048,
#         "resolution": 4.777314267823516
#       },
#       "id": "ab910c9a-242f-47e2-8c3c-debbe256a724",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene",
#         "REOrthoTile"
#       ],
#       "last_acquired": "2016-06-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2016_05_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/4c20a124-b320-4b64-a00c-5d4bc0f8e371?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/4c20a124-b320-4b64-a00c-5d4bc0f8e371/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_06_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -180,
#         -51,
#         180,
#         76
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2016-06-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 2048,
#         "resolution": 4.777314267823516
#       },
#       "id": "4c20a124-b320-4b64-a00c-5d4bc0f8e371",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene",
#         "REOrthoTile"
#       ],
#       "last_acquired": "2016-07-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2016_06_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/727c90ac-0e02-47ae-92bd-2e3b41c6395c?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/727c90ac-0e02-47ae-92bd-2e3b41c6395c/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_07_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -180,
#         -52,
#         180,
#         76
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2016-07-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 2048,
#         "resolution": 4.777314267823516
#       },
#       "id": "727c90ac-0e02-47ae-92bd-2e3b41c6395c",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene",
#         "REOrthoTile"
#       ],
#       "last_acquired": "2016-08-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2016_07_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/d887144d-e7c5-4980-8fd4-28287ff875bb?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/d887144d-e7c5-4980-8fd4-28287ff875bb/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_08_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -180,
#         -56,
#         180,
#         76
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2016-08-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 2048,
#         "resolution": 4.777314267823516
#       },
#       "id": "d887144d-e7c5-4980-8fd4-28287ff875bb",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene",
#         "REOrthoTile"
#       ],
#       "last_acquired": "2016-09-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2016_08_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/17218a40-7753-4a1d-9bcc-f0ce632c3c2b?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/17218a40-7753-4a1d-9bcc-f0ce632c3c2b/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2016_09_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -180,
#         -56,
#         180,
#         76
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2019-10-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 4096,
#         "resolution": 4.777314267823516
#       },
#       "id": "509e818d-75f3-46b4-bb88-4d46212e67fc",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene",
#         "REOrthoTile"
#       ],
#       "last_acquired": "2019-11-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2019_10_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/55fcb749-30df-4c7c-94cb-5e9832605346?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/55fcb749-30df-4c7c-94cb-5e9832605346/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_11_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -179.999999974944,
#         -57.984808013942,
#         179.999999975056,
#         65.512962548279
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2019-11-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 4096,
#         "resolution": 4.777314267823516
#       },
#       "id": "55fcb749-30df-4c7c-94cb-5e9832605346",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene",
#         "REOrthoTile"
#       ],
#       "last_acquired": "2019-12-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2019_11_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/47e57cec-91ff-46d2-bcf2-9c42d74382c4?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/47e57cec-91ff-46d2-bcf2-9c42d74382c4/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2019_12_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -179.999999974944,
#         -57.984808013942,
#         179.999999975056,
#         57.891497347472
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2019-12-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 4096,
#         "resolution": 4.777314267823516
#       },
#       "id": "47e57cec-91ff-46d2-bcf2-9c42d74382c4",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene",
#         "REOrthoTile"
#       ],
#       "last_acquired": "2020-01-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2019_12_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/fed42f53-52c0-4efc-b2b1-b6a970271645?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/fed42f53-52c0-4efc-b2b1-b6a970271645/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2020_01_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -179.999999974944,
#         -59.623325217855,
#         179.999999975056,
#         62.186013852037
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2020-01-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 4096,
#         "resolution": 4.777314267823516
#       },
#       "id": "fed42f53-52c0-4efc-b2b1-b6a970271645",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene"
#       ],
#       "last_acquired": "2020-02-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2020_01_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     },
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/0566310e-ae89-4685-a548-a34a2b09d979?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/0566310e-ae89-4685-a548-a34a2b09d979/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_monthly_2020_02_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -179.999999974944,
#         -59.623325217855,
#         179.999999975056,
#         72.607120395826
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2020-02-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 4096,
#         "resolution": 4.777314267823516
#       },
#       "id": "0566310e-ae89-4685-a548-a34a2b09d979",
#       "interval": "1 mon",
#       "item_types": [
#         "PSScene"
#       ],
#       "last_acquired": "2020-03-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_monthly_2020_02_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     }
#   ]
# }

# %%
#make get request to access mosaic from basemaps API
res = session.get("https://api.planet.com/basemaps/v1/series")

#response status code
print(res.status_code)

#print names of mosaic options
series = res.json()
names = [item['name'] for item in series['series']]
pprint(names)

# print names of global Q3 (July-Sept) mosaics
mosaic_link = [
    mosaic['_links']['mosaics'] for mosaic in series['series'] if mosaic['name'] == 'Global Quarterly'
][0]
pprint(mosaic_link)
mosaics = session.get(mosaic_link).json()
mosaic_names = [mosaic['name'] for mosaic in mosaics['mosaics'] if re.match('^.*q3.*$', mosaic['name'])]
pprint(mosaic_names)
mosaic_name = [
    mosaic_name for mosaic_name in mosaic_names if re.search("\d{4}", mosaic_name)[0] == str(year_of_interest)
]
mosaic_name
# Out:
# 200
# ['Global Monthly',
#  'Global Quarterly',
#  'PS analytic_sr biweekly subscription',
#  'PS analytic_sr daily subscription',
#  'PS analytic_sr monthly subscription',
#  'PS analytic_sr quarterly subscription',
#  'PS analytic_sr twice_monthly subscription',
#  'PS analytic_sr weekly subscription',
#  'PS normalized_analytic biweekly subscription',
#  'PS normalized_analytic daily subscription',
#  'PS normalized_analytic monthly L16 subscription',
#  'PS normalized_analytic monthly subscription',
#  'PS normalized_analytic quarterly subscription',
#  'PS normalized_analytic twice_monthly subscription',
#  'PS normalized_analytic weekly subscription',
#  'PS sen2_normalized_analytic quarterly subscription',
#  'PS visual biweekly subscription',
#  'PS visual daily subscription',
#  'PS visual twice_monthly subscription',
#  'PS visual weekly subscription']
# 'https://api.planet.com/basemaps/v1/series/060c47b7-57fb-429e-9e5b-bee1c89c6973/mosaics?api_key=PLAK0a0262a75eb34455bb250697655805f5'
# <positron-console-cell-6>:21: SyntaxWarning: invalid escape sequence '\d'
# ['global_quarterly_2016q3_mosaic',
#  'global_quarterly_2017q3_mosaic',
#  'global_quarterly_2018q3_mosaic',
#  'global_quarterly_2019q3_mosaic',
#  'global_quarterly_2020q3_mosaic',
#  'global_quarterly_2021q3_mosaic',
#  'global_quarterly_2022q3_mosaic',
#  'global_quarterly_2023q3_mosaic',
#  'global_quarterly_2024q3_mosaic',
#  'global_quarterly_2025q3_mosaic']
# ['global_quarterly_2024q3_mosaic']

# %%
# set bounding box
string_bbox = '-180,40,180,85'

#search for mosaic quad using AOI
search_parameters = {
    'bbox': string_bbox,
    'minimal': True
}

# %%
item_name = []
item_id = []
link = []
percent_covered = []
geom = []

#set params for search using name of mosaic
parameters = {
    "name__is": mosaic_name
}

#make get request to access mosaic from basemaps API
res = session.get(API_URL, params = parameters)

#response status code
print(res.status_code)

#print metadata for mosaic
mosaic = res.json()
print(json.dumps(mosaic, indent=2))

#get id
mosaic_id = mosaic['mosaics'][0]['id']

#get bbox for entire mosaic
mosaic_bbox = mosaic['mosaics'][0]['bbox']

print(mosaic_id)
print(mosaic_bbox)

#accessing quads using metadata from mosaic
quads_url = "{}/{}/quads".format(API_URL, mosaic_id)

#send request
res = session.get(quads_url, params=search_parameters, stream=True)

quads = res.json()
pprint(quads)

item_name = item_name + [mosaic_name]*len(quads['items'])
item_id = item_id + [item['id'] for item in quads['items']]
link = link + [item['_links']['download'] for item in quads['items']]
percent_covered = percent_covered + [item['percent_covered'] for item in quads['items']]
geom = geom + [
            shp.geometry.box(item['bbox'][0], item['bbox'][1], item['bbox'][2], item['bbox'][3]) 
            for item 
            in quads['items']
        ]
# print(item_id)

try:
    next_link = quads['_links']['_next']
    # print(next_link)
except:
    next_link = None

while next_link:
    res = session.get(next_link, stream=True)
    quads = res.json()

    item_name = item_name + [mosaic_name]*len(quads['items'])
    item_id = item_id + [item['id'] for item in quads['items']]
    link = link + [item['_links']['download'] for item in quads['items']]
    percent_covered = percent_covered + [item['percent_covered'] for item in quads['items']]
    geom = geom + [
        shp.geometry.box(item['bbox'][0], item['bbox'][1], item['bbox'][2], item['bbox'][3]) 
        for item 
        in quads['items']
    ]

    try:
        next_link = quads['_links']['_next']
        # print(next_link)
    except:
        next_link = None
# Out:
# 200
# {
#   "_links": {
#     "_self": "https://api.planet.com/basemaps/v1/mosaics?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#   },
#   "mosaics": [
#     {
#       "_links": {
#         "_self": "https://api.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db?api_key=PLAK0a0262a75eb34455bb250697655805f5",
#         "quads": "https://api.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads?api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox={lx},{ly},{ux},{uy}",
#         "tiles": "https://tiles.planet.com/basemaps/v1/planet-tiles/global_quarterly_2024q3_mosaic/gmap/{z}/{x}/{y}.png?api_key=PLAK0a0262a75eb34455bb250697655805f5"
#       },
#       "bbox": [
#         -179.999999974944,
#         -59.623325217855,
#         179.999999975056,
#         76.016093660188
#       ],
#       "coordinate_system": "EPSG:3857",
#       "datatype": "byte",
#       "first_acquired": "2024-07-01T00:00:00.000Z",
#       "grid": {
#         "quad_size": 4096,
#         "resolution": 4.777314267823516
#       },
#       "id": "442e78c3-e3df-4133-94e4-0b77900192db",
#       "interval": "3 mons",
#       "item_types": [
#         "PSScene"
#       ],
#       "last_acquired": "2024-10-01T00:00:00.000Z",
#       "level": 15,
#       "name": "global_quarterly_2024q3_mosaic",
#       "product_type": "timelapse",
#       "quad_download": true
#     }
#   ]
# }
# 442e78c3-e3df-4133-94e4-0b77900192db
# [-179.999999974944, -59.623325217855, 179.999999975056, 76.016093660188]
# {'_links': {'_next': 'https://api.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads?_page=370-1707&_page_size=50&api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox=-180%2C40%2C180%2C85&minimal=true',
#             '_self': 'https://api.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads?_page_size=50&api_key=PLAK0a0262a75eb34455bb250697655805f5&bbox=-180%2C40%2C180%2C85'},
#  'items': [{'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/321-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-123.57421875000001,
#                      75.97355295343336,
#                      -123.39843750000001,
#                      76.01609366420995],
#             'id': '321-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/322-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-123.39843750000001,
#                      75.97355295343336,
#                      -123.22265625000003,
#                      76.01609366420995],
#             'id': '322-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/323-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-123.22265625000003,
#                      75.97355295343336,
#                      -123.04687500000003,
#                      76.01609366420995],
#             'id': '323-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/324-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-123.04687500000001,
#                      75.97355295343336,
#                      -122.87109375000001,
#                      76.01609366420995],
#             'id': '324-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/325-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-122.87109375,
#                      75.97355295343336,
#                      -122.6953125,
#                      76.01609366420995],
#             'id': '325-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/326-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-122.6953125,
#                      75.97355295343336,
#                      -122.51953125000001,
#                      76.01609366420995],
#             'id': '326-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/327-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-122.51953125000001,
#                      75.97355295343336,
#                      -122.34375000000001,
#                      76.01609366420995],
#             'id': '327-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/328-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-122.34375000000001,
#                      75.97355295343336,
#                      -122.16796875000001,
#                      76.01609366420995],
#             'id': '328-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/329-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-122.16796875000001,
#                      75.97355295343336,
#                      -121.99218750000003,
#                      76.01609366420995],
#             'id': '329-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/330-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-121.99218750000003,
#                      75.97355295343336,
#                      -121.81640625000003,
#                      76.01609366420995],
#             'id': '330-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/331-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-121.81640625000001,
#                      75.97355295343336,
#                      -121.64062500000001,
#                      76.01609366420995],
#             'id': '331-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/332-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-121.640625,
#                      75.97355295343336,
#                      -121.46484375,
#                      76.01609366420995],
#             'id': '332-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/333-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-121.46484375,
#                      75.97355295343336,
#                      -121.28906250000001,
#                      76.01609366420995],
#             'id': '333-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/334-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-121.28906250000001,
#                      75.97355295343336,
#                      -121.11328125000001,
#                      76.01609366420995],
#             'id': '334-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/335-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-121.11328125000001,
#                      75.97355295343336,
#                      -120.93750000000001,
#                      76.01609366420995],
#             'id': '335-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/336-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-120.93750000000001,
#                      75.97355295343336,
#                      -120.76171875000003,
#                      76.01609366420995],
#             'id': '336-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/337-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-120.76171875000001,
#                      75.97355295343336,
#                      -120.58593750000001,
#                      76.01609366420995],
#             'id': '337-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/338-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-120.58593750000001,
#                      75.97355295343336,
#                      -120.41015625000001,
#                      76.01609366420995],
#             'id': '338-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/339-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-120.41015625,
#                      75.97355295343336,
#                      -120.234375,
#                      76.01609366420995],
#             'id': '339-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/340-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-120.234375,
#                      75.97355295343336,
#                      -120.05859375000001,
#                      76.01609366420995],
#             'id': '340-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/341-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-120.05859375000001,
#                      75.97355295343336,
#                      -119.88281250000001,
#                      76.01609366420995],
#             'id': '341-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/342-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-119.88281250000001,
#                      75.97355295343336,
#                      -119.70703125000001,
#                      76.01609366420995],
#             'id': '342-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/343-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-119.70703125000001,
#                      75.97355295343336,
#                      -119.53125000000003,
#                      76.01609366420995],
#             'id': '343-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/344-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-119.53125000000001,
#                      75.97355295343336,
#                      -119.35546875000001,
#                      76.01609366420995],
#             'id': '344-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/345-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-119.35546875000001,
#                      75.97355295343336,
#                      -119.17968750000001,
#                      76.01609366420995],
#             'id': '345-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/346-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-119.1796875,
#                      75.97355295343336,
#                      -119.00390625,
#                      76.01609366420995],
#             'id': '346-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/347-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-119.00390625,
#                      75.97355295343336,
#                      -118.82812500000001,
#                      76.01609366420995],
#             'id': '347-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/348-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-118.82812500000001,
#                      75.97355295343336,
#                      -118.65234375000001,
#                      76.01609366420995],
#             'id': '348-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/349-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-118.65234375000001,
#                      75.97355295343336,
#                      -118.47656250000001,
#                      76.01609366420995],
#             'id': '349-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/350-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-118.47656250000001,
#                      75.97355295343336,
#                      -118.30078125000003,
#                      76.01609366420995],
#             'id': '350-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/351-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-118.30078125000001,
#                      75.97355295343336,
#                      -118.12500000000001,
#                      76.01609366420995],
#             'id': '351-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/352-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-118.12500000000001,
#                      75.97355295343336,
#                      -117.94921875000001,
#                      76.01609366420995],
#             'id': '352-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/353-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-117.94921875,
#                      75.97355295343336,
#                      -117.7734375,
#                      76.01609366420995],
#             'id': '353-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/354-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-117.7734375,
#                      75.97355295343336,
#                      -117.59765625000001,
#                      76.01609366420995],
#             'id': '354-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/355-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-117.59765625000001,
#                      75.97355295343336,
#                      -117.42187500000001,
#                      76.01609366420995],
#             'id': '355-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/356-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-117.42187500000001,
#                      75.97355295343336,
#                      -117.24609375000001,
#                      76.01609366420995],
#             'id': '356-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/357-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-117.24609375000001,
#                      75.97355295343336,
#                      -117.07031250000003,
#                      76.01609366420995],
#             'id': '357-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/358-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-117.07031250000001,
#                      75.97355295343336,
#                      -116.89453125000001,
#                      76.01609366420995],
#             'id': '358-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/359-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-116.89453125000001,
#                      75.97355295343336,
#                      -116.71875000000001,
#                      76.01609366420995],
#             'id': '359-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/360-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-116.71875,
#                      75.97355295343336,
#                      -116.54296875,
#                      76.01609366420995],
#             'id': '360-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/361-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-116.54296875,
#                      75.97355295343336,
#                      -116.36718750000001,
#                      76.01609366420995],
#             'id': '361-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/362-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-116.36718750000001,
#                      75.97355295343336,
#                      -116.19140625000001,
#                      76.01609366420995],
#             'id': '362-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/363-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-116.19140625000001,
#                      75.97355295343336,
#                      -116.01562500000001,
#                      76.01609366420995],
#             'id': '363-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/364-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-116.01562500000001,
#                      75.97355295343336,
#                      -115.83984375000003,
#                      76.01609366420995],
#             'id': '364-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/365-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-115.83984375000001,
#                      75.97355295343336,
#                      -115.66406250000001,
#                      76.01609366420995],
#             'id': '365-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/366-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-115.66406250000001,
#                      75.97355295343336,
#                      -115.48828125000001,
#                      76.01609366420995],
#             'id': '366-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/367-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-115.48828125,
#                      75.97355295343336,
#                      -115.3125,
#                      76.01609366420995],
#             'id': '367-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/368-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-115.3125,
#                      75.97355295343336,
#                      -115.13671875000001,
#                      76.01609366420995],
#             'id': '368-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/369-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-115.13671875000001,
#                      75.97355295343336,
#                      -114.96093750000001,
#                      76.01609366420995],
#             'id': '369-1707',
#             'percent_covered': None},
#            {'_links': {'download': 'https://link.planet.com/basemaps/v1/mosaics/442e78c3-e3df-4133-94e4-0b77900192db/quads/370-1707/full?api_key=PLAK0a0262a75eb34455bb250697655805f5'},
#             'bbox': [-114.96093750000001,
#                      75.97355295343336,
#                      -114.78515625000001,
#                      76.01609366420995],
#             'id': '370-1707',
#             'percent_covered': None}]}

# %%
# # Troubleshooting

# print(mosaic_name)
# print(next_link)
# print(res)
# res.reason

# %%
# # More Troubleshooting

# problem_link = next_link
# print(problem_link)

# %%
# # More Troubleshooting

# test_response = session.get(next_link, stream=True)
# info = test_response.json()
# info

# %%
circumpolar_grids = gpd.GeoDataFrame(
    data = pd.DataFrame({
        'name': item_name,
        'id': item_id,
        'link': link,
        'percent_covered': percent_covered,
    }),
    geometry = gpd.GeoSeries(
        data = geom,
        crs = 'EPSG:4326'
    )
)

circumpolar_grids
# Out:
#                                     name         id                                               link  \
# 0       [global_quarterly_2024q3_mosaic]   321-1707  https://link.planet.com/basemaps/v1/mosaics/44...
# 1       [global_quarterly_2024q3_mosaic]   322-1707  https://link.planet.com/basemaps/v1/mosaics/44...
# 2       [global_quarterly_2024q3_mosaic]   323-1707  https://link.planet.com/basemaps/v1/mosaics/44...
# 3       [global_quarterly_2024q3_mosaic]   324-1707  https://link.planet.com/basemaps/v1/mosaics/44...
# 4       [global_quarterly_2024q3_mosaic]   325-1707  https://link.planet.com/basemaps/v1/mosaics/44...
# ...                                  ...        ...                                                ...
# 526273  [global_quarterly_2024q3_mosaic]  1828-1272  https://link.planet.com/basemaps/v1/mosaics/44...
# 526274  [global_quarterly_2024q3_mosaic]  1829-1272  https://link.planet.com/basemaps/v1/mosaics/44...
# 526275  [global_quarterly_2024q3_mosaic]  1830-1272  https://link.planet.com/basemaps/v1/mosaics/44...
# 526276  [global_quarterly_2024q3_mosaic]  1831-1272  https://link.planet.com/basemaps/v1/mosaics/44...
# 526277  [global_quarterly_2024q3_mosaic]  1832-1272  https://link.planet.com/basemaps/v1/mosaics/44...
#
#        percent_covered                                           geometry
# 0                 None  POLYGON ((-123.39844 75.97355, -123.39844 76.0...
# 1                 None  POLYGON ((-123.22266 75.97355, -123.22266 76.0...
# 2                 None  POLYGON ((-123.04688 75.97355, -123.04688 76.0...
# 3                 None  POLYGON ((-122.87109 75.97355, -122.87109 76.0...
# 4                 None  POLYGON ((-122.69531 75.97355, -122.69531 76.0...
# ...                ...                                                ...
# 526273            None  POLYGON ((141.50391 39.90974, 141.50391 40.044...
# 526274            None  POLYGON ((141.67969 39.90974, 141.67969 40.044...
# 526275            None  POLYGON ((141.85547 39.90974, 141.85547 40.044...
# 526276            None  POLYGON ((142.03125 39.90974, 142.03125 40.044...
# 526277            None  POLYGON ((142.20703 39.90974, 142.20703 40.044...
#
# [526278 rows x 5 columns]

# %%
circumpolar_grids.to_file('../data/circumpolar_global_basemap_grids_2024.geojson')
